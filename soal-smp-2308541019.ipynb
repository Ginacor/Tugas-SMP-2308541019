# %%
import math
x = (-1+(5)**1/2)/2
log1 = x**2024-x**2025
log2 = (x*(1-x))
print(log1)
print(log2)

pembilang= math.log(x**2024-x**2025)
penyebut = math.log(x*(1-x))

n = pembilang/penyebut
print(n)
# Out:
# 3.3261138715251087e-254
# 0.1875
# 348.6636951980335
